# %% [markdown]
# ### Basic import & Helper function

# %%
import pickle
import re
import pandas as pd
import numpy as np
import random

# %%
file_path = 'data/ratings_retail_indus.pkl'

# %%
with open(file_path, 'rb') as f:
    data = pickle.load(f)

# %%
df = pd.DataFrame(data)
df = df.T
df
# Out:
#      2010Q1 2010Q2 2010Q3 2010Q4 2011Q1 2011Q2 2011Q3 2011Q4 2012Q1 2012Q2  \
# AAL      B-     B-     B-     B-     B-     B-     B-     B-      D      D
# AAP     BB+    BB+   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-
# ABG      B+     B+     B+     B+     B+     B+     B+     B+     B+     B+
# ACCO     B+     B+     B+     B+     B+     B+     B+     B+     B+     B+
# ACM     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# WWW     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# WYNN     BB     BB     BB     BB     BB     BB    BB+    BB+    BB+    BB+
# XPO     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# XYL     NaN    NaN    NaN    NaN    NaN    NaN    NaN    BBB    BBB    BBB
# YUM    BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-    BBB
#
#       ... 2021Q4 2022Q1 2022Q2 2022Q3 2022Q4 2023Q1 2023Q2 2023Q3 2023Q4  \
# AAL   ...    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-
# AAP   ...   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-   BBB-
# ABG   ...    BB+    BB+    BB+    BB+    BB+    BB+    BB+    BB+    BB+
# ACCO  ...    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-
# ACM   ...     BB     BB     BB     BB     BB     BB     BB     BB     BB
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# WWW   ...    BB+    BB+    BB+    BB+    BB+    BB+    BB+    BB+    BB+
# WYNN  ...    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-    BB-
# XPO   ...     B+     B+     B+     B+     B+     B+     B+     B+     B+
# XYL   ...    BBB    BBB    BBB    BBB    BBB    BBB    BBB    BBB    BBB
# YUM   ...     BB     BB     BB     BB     BB     BB     BB     BB     BB
#
#      2024Q1
# AAL     BB-
# AAP    BBB-
# ABG     BB+
# ACCO    BB-
# ACM      BB
# ...     ...
# WWW     BB+
# WYNN    BB-
# XPO      B+
# XYL     BBB
# YUM      BB
#
# [392 rows x 57 columns]

# %%
rating_order = [
    'D', 'CCC-', 'CCC', 'CCC+', 'CC', 
    'B-', 'B', 'B+', 'BB-', 'BB', 'BB+', 
    'BBB-', 'BBB', 'BBB+', 'A-', 'A', 'A+', 
    'AA-', 'AA', 'AA+', 'AAA'
]

# %%
rating_to_num = {rating: i for i, rating in enumerate(rating_order)}

# %%
def rating_to_numeric(rating):
    if pd.isna(rating):
        return None
    return rating_to_num.get(rating, None)

# %%
df_num = df.applymap(rating_to_numeric)

# %%
df_diff = df_num.diff(axis=1)

# %%
first_quarter = df.iloc[:, 0]
df_diff.iloc[:, 0] = first_quarter.apply(lambda x: 0 if pd.notna(x) else None)
# Out:
# AAL       B-
# AAP      BB+
# ABG       B+
# ACCO      B+
# ACM      NaN
#         ...
# WWW      NaN
# WYNN      BB
# XPO      NaN
# XYL      NaN
# YUM     BBB-
# Name: 2010Q1, Length: 392, dtype: object

# %%
def count_changes(diff_df):
    no_change = (diff_df == 0).sum().sum()
    increase = (diff_df > 0).sum().sum()
    decrease = (diff_df < 0).sum().sum()
    return no_change, increase, decrease

# %%
no_change, increase, decrease = count_changes(df_diff)
print(f"No Change: {no_change}")
print(f"Increase: {increase}")
print(f"Decrease: {decrease}")
# Out:
# No Change: 19962
# Increase: 357
# Decrease: 168

# %%
def extract_ratings_by_change_type(df, df_diff):
    increase = []
    decrease = []
    no_change = []
    for company in df.index:
        for quarter in df.columns:
            if df_diff.loc[company, quarter] > 0:
                increase.append((company, quarter))
            elif df_diff.loc[company, quarter] < 0:
                decrease.append((company, quarter))
            elif df_diff.loc[company, quarter] == 0:
                no_change.append((company, quarter))
    
    return increase, decrease, no_change

# %%
increase, decrease, no_change = extract_ratings_by_change_type(df, df_diff)

# %%
num_samples = min(len(increase), len(decrease), len(no_change))

# %%
selected_increase = random.sample(increase, num_samples)
selected_decrease = random.sample(decrease, num_samples)
selected_no_change = random.sample(no_change, num_samples)

# %%
selected_data = selected_increase + selected_decrease + selected_no_change

# %%
final_ratings = {}
for company, quarter in selected_data:
    if company not in final_ratings:
        final_ratings[company] = {}
    final_ratings[company][quarter] = df.loc[company, quarter]

# %%
print("Final Ratings:", final_ratings)
# Out:
# Final Ratings: {'AL': {'2017Q1': 'BBB', '2020Q3': 'BBB'}, 'CAL': {'2010Q2': 'B', '2015Q1': 'BB-', '2014Q1': 'B+', '2010Q4': 'B+', '2012Q1': 'B'}, 'GT': {'2015Q3': 'BB'}, 'DAN': {'2014Q2': 'BB+', '2012Q2': 'BB', '2010Q3': 'B+'}, 'GBX': {'2012Q2': 'B', '2013Q1': 'B+', '2020Q3': 'BB', '2023Q4': 'BB'}, 'SRI': {'2011Q3': 'BB-', '2014Q4': 'BB', '2019Q2': 'BB'}, 'UNP': {'2012Q3': 'A-', '2011Q1': 'BBB+'}, 'HA': {'2015Q3': 'B+', '2016Q3': 'BB-'}, 'LEVI': {'2014Q1': 'BB-', '2017Q1': 'BB+'}, 'RCL': {'2015Q4': 'BB+', '2011Q1': 'BB'}, 'LII': {'2014Q2': 'BBB', '2014Q4': 'BBB', '2014Q3': 'BBB'}, 'ENOV': {'2015Q2': 'BB+'}, 'CAR': {'2010Q2': 'B+', '2014Q3': 'BB-', '2017Q1': 'BB'}, 'LKQ': {'2010Q3': 'BB', '2011Q3': 'BB+', '2016Q2': 'BB'}, 'ITT': {'2016Q3': 'BBB', '2012Q1': 'BBB-'}, 'WAB': {'2015Q3': 'BBB', '2011Q3': 'BB+'}, 'OSK': {'2010Q4': 'BB-', '2014Q1': 'BB+'}, 'IHG': {'2011Q3': 'BBB'}, 'GLDD': {'2015Q1': 'B', '2013Q4': 'B-', '2016Q1': 'B-', '2015Q3': 'B'}, 'CPS': {'2013Q2': 'BB-'}, 'M': {'2011Q3': 'BBB-', '2014Q1': 'BBB+', '2010Q3': 'BB+', '2017Q2': 'BBB-', '2016Q2': 'BBB'}, 'ALGT': {'2015Q3': 'BB', '2016Q4': 'BB-', '2022Q3': 'BB-'}, 'BRFS': {'2015Q3': 'BBB'}, 'TPX': {'2016Q2': 'BB'}, 'HII': {'2015Q1': 'BB+', '2014Q2': 'BB'}, 'SFM': {'2015Q3': 'BB', '2014Q2': 'BB-', '2020Q2': 'BB'}, 'KAR': {'2015Q4': 'BB-', '2015Q3': 'B+'}, 'HOG': {'2013Q4': 'A-'}, 'SBUX': {'2012Q2': 'A-', '2017Q1': 'A', '2013Q4': 'A-'}, 'ALK': {'2013Q4': 'BB', '2010Q4': 'B+', '2017Q1': 'BB+', '2017Q3': 'BB+'}, 'RL': {'2011Q2': 'A-'}, 'KO': {'2012Q4': 'AA-', '2014Q3': 'AA', '2016Q2': 'AA-', '2011Q2': 'A+'}, 'SAH': {'2011Q4': 'BB-', '2016Q4': 'BB-', '2011Q3': 'B+'}, 'AN': {'2011Q4': 'BBB-', '2013Q1': 'BBB-'}, 'FCN': {'2016Q4': 'BB+', '2014Q2': 'BB'}, 'GMS': {'2016Q4': 'B+'}, 'OLLI': {'2015Q4': 'B+'}, 'ORLY': {'2012Q2': 'BBB', '2015Q2': 'BBB+'}, 'CMI': {'2010Q4': 'BBB+', '2011Q4': 'A', '2012Q1': 'A'}, 'KOF': {'2010Q2': 'A-'}, 'STZ': {'2011Q3': 'BB+'}, 'GPI': {'2012Q3': 'BB'}, 'GD': {'2015Q4': 'A+', '2018Q4': 'A+'}, 'PHM': {'2013Q3': 'BB', '2010Q4': 'BB-', '2017Q2': 'BB+'}, 'LVS': {'2011Q1': 'BB-', '2014Q1': 'BBB-', '2010Q4': 'B', '2012Q3': 'BB+'}, 'BC': {'2014Q3': 'BB+', '2013Q3': 'BB', '2012Q3': 'BB-'}, 'NVR': {'2015Q3': 'BBB+', '2018Q3': 'BBB+'}, 'DG': {'2016Q1': 'BBB', '2010Q3': 'BB', '2022Q4': 'BBB', '2020Q4': 'BBB'}, 'GEO': {'2015Q1': 'BB-', '2011Q2': 'B+'}, 'CWH': {'2014Q4': 'B+'}, 'CNI': {'2014Q1': 'A'}, 'LUV': {'2015Q1': 'BBB', '2011Q3': 'BBB-', '2016Q3': 'BBB'}, 'VMI': {'2013Q3': 'BBB', '2014Q4': 'BBB+'}, 'DDS': {'2013Q2': 'BB+', '2011Q2': 'BB-'}, 'PPC': {'2014Q3': 'BB', '2015Q3': 'BB+', '2011Q4': 'B', '2016Q4': 'BB'}, 'JBLU': {'2016Q1': 'BB-', '2015Q3': 'B+', '2011Q3': 'B-', '2024Q1': 'BB-'}, 'MTW': {'2014Q2': 'BB-', '2017Q1': 'B', '2011Q1': 'B+', '2016Q2': 'B+'}, 'WNC': {'2014Q4': 'BB-'}, 'BLMN': {'2014Q1': 'BB-', '2015Q1': 'BB', '2015Q4': 'BB'}, 'DAL': {'2014Q1': 'BB-', '2015Q4': 'BB+', '2015Q1': 'BB'}, 'RSG': {'2014Q1': 'BBB+'}, 'LEN': {'2014Q4': 'BB', '2011Q1': 'B+'}, 'FL': {'2011Q2': 'BB-', '2012Q2': 'BB', '2013Q1': 'BB+'}, 'VATE': {'2015Q1': 'B', '2016Q1': 'B-', '2014Q4': 'B-'}, 'SBH': {'2011Q3': 'BB', '2014Q4': 'BB+'}, 'NCLH': {'2011Q3': 'B+', '2013Q2': 'BB-'}, 'MHK': {'2012Q2': 'BBB-', '2013Q4': 'BBB'}, 'ETD': {'2013Q1': 'BB-'}, 'THS': {'2014Q2': 'BB'}, 'ARC': {'2014Q4': 'BB-', '2011Q4': 'B+'}, 'CXW': {'2013Q2': 'BB+', '2016Q4': 'BB'}, 'CHD': {'2013Q3': 'BBB+'}, 'TILE': {'2015Q1': 'BB+'}, 'BLDR': {'2013Q3': 'B', '2015Q4': 'B+', '2010Q2': 'CCC+', '2011Q3': 'CCC'}, 'MAS': {'2015Q1': 'BBB', '2012Q1': 'BBB-'}, 'BBWI': {'2011Q2': 'BB+'}, 'CSX': {'2014Q1': 'BBB+'}, 'HXL': {'2011Q3': 'BB+'}, 'BKNG': {'2014Q4': 'BBB+'}, 'F': {'2010Q4': 'B+', '2022Q1': 'BBB'}, 'PFMT': {'2013Q2': 'BB-', '2015Q3': 'B+'}, 'DAR': {'2012Q2': 'BB+', '2011Q2': 'BB'}, 'ROST': {'2013Q3': 'A-', '2011Q3': 'BBB+', '2021Q3': 'A-'}, 'FUN': {'2014Q1': 'BB', '2012Q2': 'BB-', '2023Q2': 'BB', '2011Q2': 'B+'}, 'GM': {'2011Q4': 'BB+', '2011Q1': 'BB-', '2014Q4': 'BBB-'}, 'MHO': {'2016Q4': 'B+', '2023Q3 ...

# %%
final_ratings
# Out:
# {'AL': {'2017Q1': 'BBB', '2020Q3': 'BBB'},
#  'CAL': {'2010Q2': 'B',
#   '2015Q1': 'BB-',
#   '2014Q1': 'B+',
#   '2010Q4': 'B+',
#   '2012Q1': 'B'},
#  'GT': {'2015Q3': 'BB'},
#  'DAN': {'2014Q2': 'BB+', '2012Q2': 'BB', '2010Q3': 'B+'},
#  'GBX': {'2012Q2': 'B', '2013Q1': 'B+', '2020Q3': 'BB', '2023Q4': 'BB'},
#  'SRI': {'2011Q3': 'BB-', '2014Q4': 'BB', '2019Q2': 'BB'},
#  'UNP': {'2012Q3': 'A-', '2011Q1': 'BBB+'},
#  'HA': {'2015Q3': 'B+', '2016Q3': 'BB-'},
#  'LEVI': {'2014Q1': 'BB-', '2017Q1': 'BB+'},
#  'RCL': {'2015Q4': 'BB+', '2011Q1': 'BB'},
#  'LII': {'2014Q2': 'BBB', '2014Q4': 'BBB', '2014Q3': 'BBB'},
#  'ENOV': {'2015Q2': 'BB+'},
#  'CAR': {'2010Q2': 'B+', '2014Q3': 'BB-', '2017Q1': 'BB'},
#  'LKQ': {'2010Q3': 'BB', '2011Q3': 'BB+', '2016Q2': 'BB'},
#  'ITT': {'2016Q3': 'BBB', '2012Q1': 'BBB-'},
#  'WAB': {'2015Q3': 'BBB', '2011Q3': 'BB+'},
#  'OSK': {'2010Q4': 'BB-', '2014Q1': 'BB+'},
#  'IHG': {'2011Q3': 'BBB'},
#  'GLDD': {'2015Q1': 'B', '2013Q4': 'B-', '2016Q1': 'B-', '2015Q3': 'B'},
#  'CPS': {'2013Q2': 'BB-'},
#  'M': {'2011Q3': 'BBB-',
#   '2014Q1': 'BBB+',
#   '2010Q3': 'BB+',
#   '2017Q2': 'BBB-',
#   '2016Q2': 'BBB'},
#  'ALGT': {'2015Q3': 'BB', '2016Q4': 'BB-', '2022Q3': 'BB-'},
#  'BRFS': {'2015Q3': 'BBB'},
#  'TPX': {'2016Q2': 'BB'},
#  'HII': {'2015Q1': 'BB+', '2014Q2': 'BB'},
#  'SFM': {'2015Q3': 'BB', '2014Q2': 'BB-', '2020Q2': 'BB'},
#  'KAR': {'2015Q4': 'BB-', '2015Q3': 'B+'},
#  'HOG': {'2013Q4': 'A-'},
#  'SBUX': {'2012Q2': 'A-', '2017Q1': 'A', '2013Q4': 'A-'},
#  'ALK': {'2013Q4': 'BB', '2010Q4': 'B+', '2017Q1': 'BB+', '2017Q3': 'BB+'},
#  'RL': {'2011Q2': 'A-'},
#  'KO': {'2012Q4': 'AA-', '2014Q3': 'AA', '2016Q2': 'AA-', '2011Q2': 'A+'},
#  'SAH': {'2011Q4': 'BB-', '2016Q4': 'BB-', '2011Q3': 'B+'},
#  'AN': {'2011Q4': 'BBB-', '2013Q1': 'BBB-'},
#  'FCN': {'2016Q4': 'BB+', '2014Q2': 'BB'},
#  'GMS': {'2016Q4': 'B+'},
#  'OLLI': {'2015Q4': 'B+'},
#  'ORLY': {'2012Q2': 'BBB', '2015Q2': 'BBB+'},
#  'CMI': {'2010Q4': 'BBB+', '2011Q4': 'A', '2012Q1': 'A'},
#  'KOF': {'2010Q2': 'A-'},
#  'STZ': {'2011Q3': 'BB+'},
#  'GPI': {'2012Q3': 'BB'},
#  'GD': {'2015Q4': 'A+', '2018Q4': 'A+'},
#  'PHM': {'2013Q3': 'BB', '2010Q4': 'BB-', '2017Q2': 'BB+'},
#  'LVS': {'2011Q1': 'BB-', '2014Q1': 'BBB-', '2010Q4': 'B', '2012Q3': 'BB+'},
#  'BC': {'2014Q3': 'BB+', '2013Q3': 'BB', '2012Q3': 'BB-'},
#  'NVR': {'2015Q3': 'BBB+', '2018Q3': 'BBB+'},
#  'DG': {'2016Q1': 'BBB', '2010Q3': 'BB', '2022Q4': 'BBB', '2020Q4': 'BBB'},
#  'GEO': {'2015Q1': 'BB-', '2011Q2': 'B+'},
#  'CWH': {'2014Q4': 'B+'},
#  'CNI': {'2014Q1': 'A'},
#  'LUV': {'2015Q1': 'BBB', '2011Q3': 'BBB-', '2016Q3': 'BBB'},
#  'VMI': {'2013Q3': 'BBB', '2014Q4': 'BBB+'},
#  'DDS': {'2013Q2': 'BB+', '2011Q2': 'BB-'},
#  'PPC': {'2014Q3': 'BB', '2015Q3': 'BB+', '2011Q4': 'B', '2016Q4': 'BB'},
#  'JBLU': {'2016Q1': 'BB-', '2015Q3': 'B+', '2011Q3': 'B-', '2024Q1': 'BB-'},
#  'MTW': {'2014Q2': 'BB-', '2017Q1': 'B', '2011Q1': 'B+', '2016Q2': 'B+'},
#  'WNC': {'2014Q4': 'BB-'},
#  'BLMN': {'2014Q1': 'BB-', '2015Q1': 'BB', '2015Q4': 'BB'},
#  'DAL': {'2014Q1': 'BB-', '2015Q4': 'BB+', '2015Q1': 'BB'},
#  'RSG': {'2014Q1': 'BBB+'},
#  'LEN': {'2014Q4': 'BB', '2011Q1': 'B+'},
#  'FL': {'2011Q2': 'BB-', '2012Q2': 'BB', '2013Q1': 'BB+'},
#  'VATE': {'2015Q1': 'B', '2016Q1': 'B-', '2014Q4': 'B-'},
#  'SBH': {'2011Q3': 'BB', '2014Q4': 'BB+'},
#  'NCLH': {'2011Q3': 'B+', '2013Q2': 'BB-'},
#  'MHK': {'2012Q2': 'BBB-', '2013Q4': 'BBB'},
#  'ETD': {'2013Q1': 'BB-'},
#  'THS': {'2014Q2': 'BB'},
#  'ARC': {'2014Q4': 'BB-', '2011Q4': 'B+'},
#  'CXW': {'2013Q2': 'BB+', '2016Q4': 'BB'},
#  'CHD': {'2013Q3': 'BBB+'},
#  'TILE': {'2015Q1': 'BB+'},
#  'BLDR': {'2013Q3': 'B', '2015Q4': 'B+', '2010Q2': 'CCC+', '2011Q3': 'CCC'},
#  'MAS': {'2015Q1': 'BBB', '2012Q1': 'BBB-'},
#  'BBWI': {'2011Q2': 'BB+'},
#  'CSX': {'2014Q1': 'BBB+'},
#  'HXL': {'2011Q3': 'BB+'},
#  'BKNG': {'2014Q4': 'BBB+'},
#  'F': {'2010Q4': 'B+', '2022Q1': 'BBB'},
#  'PFMT': {'2013Q2': 'BB-', '2015Q3': 'B+'},
#  'DAR': {'2012Q2': 'BB+', '2011Q2': 'BB'},
#  'ROST': {'2013Q3': 'A-', '2011Q3': 'BBB+', '2021Q3': 'A-'},
#  'FUN': {'2014Q1': 'BB', '2012Q2': 'BB-', '2023Q2': 'BB', '2011Q2': 'B+'},
#  'GM': {'2011Q4': 'BB+', '2011Q1': 'BB-', '2014Q4': 'BBB-'},
#  'MHO': {'2016Q4': 'B+', '2023Q3': 'B+'},
#  'CWST': {'2016Q2': 'B', '2012Q2': 'B', '2013Q2': 'B-', '2017Q2': 'B'},
#  'FLS': {'2015Q2': 'BBB', '2018Q4': 'BBB'},
#  'LEA': {'2016Q1': 'BBB-'},
#  'HD': {'2012Q1': 'A-'},
#  'SEE': {'2014Q1': 'BB', '2011Q4': 'BB', '2012Q4': 'BB-'},
#  'PNR': {'2012Q4': 'BBB', '2016Q2': 'BBB-'},
#  'AAL': {'2015Q3': 'BB-', '2014Q1': 'B', '2015Q1': 'B+', '2012Q1': 'D'},
#  'UFI': {'2011Q1': 'B', '2019Q4': 'B'},
#  'HLT': {'2016Q3': 'BB+'},
#  'TJX': {'2014Q1': 'A+', '2021Q2': 'A+'},
#  'KEX': {'2010Q2': 'A-', '2016Q2': 'BBB+'},
#  'MGA': {'2011Q3': 'BBB+', '2014Q1': 'A-', '2015Q4': 'A-'},
#  'TSN': {'2010Q4': 'BB+', '2011Q2': 'BBB-', '2013Q2': 'BBB'},
#  'GCO': {'2010Q3': 'BB-', '2015Q2': 'BB', '2018Q1': 'BB'},
#  'BIG': {'2015Q4': 'BBB', '2013Q1': 'BBB-', '2018Q2': 'BBB'},
#  'MO': {'2016Q2': 'A-'},
#  'ACCO': {'2012Q3': 'BB-', '2019Q4': 'BB-'},
#  'JCI': {'2011Q1': 'BBB+'},
#  'TXT': {'2015Q2': 'BBB'},
#  'DOOO': {'2014Q3': 'BB-'},
#  'ROCK': {'2017Q2': 'BB', '2016Q2': 'BB-'},
#  'CENTA': {'2016Q1': 'BB-', '2013Q2': 'B', '2021Q4': 'BB-', '2020Q2': 'BB-'},
#  'BFAM': {'2015Q3': 'BB-'},
#  'WCN': {'2014Q4': 'BBB+', '2013Q1': 'BBB-'},
#  'BWA': {'2012Q3': 'BBB+'},
#  'ALSN': {'2012Q1': 'B+'},
#  'BG': {'2016Q1': 'BBB'},
#  'XPO': {'2016Q4': 'B+'},
#  'VFC': {'2014Q3': 'A', '2018Q4': 'A'},
#  'LHX': {'2015Q3': 'BBB-', '2021Q1': 'BBB-'},
#  'BCO': {'2013Q4': 'BBB-'},
#  'HLF': {'2017Q2': 'BB-', '2014Q2': 'BB+'},
#  'ATI': {'2016Q3': 'B',
#   '2016Q1': 'BB-',
#   '2016Q2': 'B+',
#   '2015Q2': 'BB+',
#   '2021Q4': 'B'},
#  'GPS': {'2016Q3': 'BB+', '2018Q3': 'BB+', '2012Q2': 'BB+'},
#  'GME': {'2017Q2': 'BB'},
#  'PBI': {'2013Q1': 'BBB',
#   '2010Q4': 'BBB+',
#   '2017Q1': 'BBB-',
#   '2011Q1': 'BBB+'},
#  'GHC': {'2011Q4': 'A-',
#   '2012Q4': 'BBB',
#   '2012Q1': 'BBB+',
#   '2015Q4': 'BB+',
#   '2011Q2': 'A'},
#  'HAS': {'2013Q2': 'BBB', '2024Q1': 'BBB', '2020Q1': 'BBB', '2011Q4': 'BBB+'},
#  'CP': {'2011Q3': 'BBB-'},
#  'HOV': {'2012Q1': 'CCC-', '2016Q3': 'CCC+', '2011Q3': 'CCC'},
#  'MLKN': {'2010Q4': 'BBB-', '2012Q4': 'BBB-'},
#  'LOW': {'2012Q1': 'A-', '2010Q3': 'A', '2023Q1': 'A-', '2023Q3': 'A-'},
#  'TGT': {'2014Q2': 'A'},
#  'CPB': {'2012Q1': 'A-', '2012Q4': 'BBB+', '2012Q3': 'A-'},
#  'GWW': {'2015Q3': 'AA', '2015Q4': 'AA-'},
#  'LPX': {'2015Q4': 'BB-'},
#  'CCK': {'2014Q3': 'BB'},
#  'GE': {'2016Q4': 'AA-'},
#  'KTOS': {'2012Q3': 'B', '2015Q1': 'B-'},
#  'TWI': {'2015Q3': 'B', '2015Q4': 'B-'},
#  'KODK': {'2011Q2': 'CCC', '2012Q2': 'D', '2018Q1': 'B-'},
#  'BBY': {'2012Q4': 'BB+', '2013Q1': 'BB'},
#  'BTI': {'2017Q2': 'BBB+'},
#  'SYY': {'2011Q2': 'A+', '2015Q4': 'A-', '2013Q2': 'A', '2016Q2': 'BBB+'},
#  'PRMW': {'2015Q1': 'B'},
#  'PENN': {'2015Q3': 'B+', '2014Q1': 'BB-'},
#  'TGI': {'2015Q4': 'BB', '2016Q3': 'BB-'},
#  'CRS': {'2017Q1': 'BBB-', '2023Q3': 'BBB-'},
#  'CTAS': {'2011Q3': 'BBB+', '2016Q4': 'BBB+'},
#  'WYNN': {'2015Q4': 'BB', '2017Q1': 'BB-', '2023Q4': 'BB-'},
#  'EAF': {'2016Q1': 'B', '2015Q1': 'BB-', '2016Q2': 'CCC+', '2015Q4': 'B+'},
#  'CAG': {'2013Q1': 'BBB-', '2010Q1': 'BBB'},
#  'KBH': {'2010Q4': 'B+', '2012Q2': 'B'},
#  'ODP': {'2011Q4': 'B-'},
#  'KMT': {'2016Q4': 'BBB-', '2011Q4': 'BBB'},
#  'JWN': {'2016Q2': 'BBB+'},
#  'OI': {'2015Q4': 'BB', '2014Q1': 'BB+'},
#  'LEG': {'2011Q1': 'BBB+', '2010Q3': 'A-'},
#  'WW': {'2014Q3': 'B', '2015Q3': 'B-', '2014Q2': 'B+', '2013Q2': 'BB-'},
#  'FOSL': {'2016Q3': 'BB+', '2017Q2': 'BB', '2020Q4': 'BB'},
#  'NVRI': {'2015Q3': 'BB',
#   '2013Q2': 'BBB-',
#   '2016Q2': 'BB-',
#   '2011Q2': 'BBB+',
#   '2014Q1': 'BB+',
#   '2012Q2': 'BBB'},
#  'MCD': {'2016Q1': 'BBB+', '2015Q3': 'A-', '2011Q4': 'A'},
#  'LNW': {'2013Q3': 'BB-', '2014Q4': 'B+', '2016Q4': 'B'},
#  'LE': {'2016Q3': 'B-', '2016Q2': 'B'},
#  'QUAD': {'2014Q3': 'BB-', '2013Q1': 'BB'},
#  'CCEP': {'2011Q1': 'BBB+'},
#  'LMT': {'2016Q1': 'BBB+', '2012Q4': 'A-'},
#  'SCS': {'2010Q2': 'BBB-'},
#  'KSS': {'2017Q2': 'BBB-', '2015Q1': 'BBB'},
#  'EBAY': {'2015Q4': 'BBB+'},
#  'UPS': {'2012Q4': 'A+'},
#  'TAP': {'2016Q1': 'BBB-'},
#  'UAA': {'2017Q2': 'BB+'},
#  'STKL': {'2016Q4': 'B-'},
#  'TT': {'2013Q3': 'BBB'},
#  'WEN': {'2015Q3': 'B'},
#  'IR': {'2013Q4': 'B', '2018Q3': 'B'},
#  'PCAR': {'2010Q3': 'A+', '2017Q1': 'A+', '2022Q1': 'A+'},
#  'GATX': {'2010Q4': 'BBB', '2014Q1': 'BBB'},
#  'BYD': {'2011Q1': 'B', '2010Q3': 'B+', '2022Q4': 'B+'},
#  'YUM': {'2016Q1': 'BB'},
#  'CHH': {'2012Q3': 'BB+', '2010Q1': 'BBB'},
#  'POST': {'2014Q1': 'B', '2015Q4': 'B'},
#  'HI': {'2013Q1': 'BBB-', '2011Q1': 'BBB'},
#  'PRKS': {'2014Q4': 'BB-', '2012Q2': 'B+', '2014Q3': 'BB'},
#  'R': {'2012Q4': 'BBB', '2018Q4': 'BBB+'},
#  'MAT': {'2015Q2': 'BBB'},
#  'TOL': {'2011Q3': 'BB+', '2019Q4': 'BB+', '2015Q1': 'BB+', '2019Q1': 'BB+'},
#  'CMCO': {'2017Q2': 'B+'},
#  'KHC': {'2013Q3': 'BB-'},
#  'PEP': {'2010Q2': 'A'},
#  'DOV': {'2016Q3': 'A-', '2016Q1': 'A'},
#  'K': {'2016Q1': 'BBB'},
#  'GEF': {'2013Q4': 'BB'},
#  'TM': {'2011Q2': 'AA-', '2019Q1': 'AA-'},
#  'EPC': {'2015Q4': 'BB+', '2018Q3': 'BB+'},
#  'SJM': {'2015Q2': 'BBB'},
#  'RTX': {'2015Q4': 'A-'},
#  'EAT': {'2016Q4': 'BB+', '2011Q2': 'BBB-'},
#  'TRI': {'2014Q1': 'BBB+'},
#  'PVH': {'2010Q3': 'BB+'},
#  'ADP': {'2014Q3': 'AA'},
#  'MDLZ': {'2010Q2': 'BBB'},
#  'DRI': {'2014Q1': 'BBB-'},
#  'MTH': {'2017Q4': 'BB-'},
#  'LOCO': {'2023Q4': 'B', '2022Q1': 'B'},
#  'MUSA': {'2016Q2': 'BB+'},
#  'DENN': {'2013Q4': 'B+', '2021Q3': 'B+', '2015Q3': 'B+'},
#  'HGV': {'2017Q2': 'BB+', '2018Q2': 'BB+'},
#  'AME': {'2013Q2': 'BBB'},
#  'MOG.A': {'2014Q1': 'BB'},
#  'FTAI': {'2022Q3': 'B', '2016Q3': 'B'},
#  'TRN': {'2023Q1': 'BBB-', '2019Q1': 'BBB-'},
#  'ARCB': {'2023Q3': 'BB+', '2018Q2': 'BB+'},
#  'AMZN': {'2021Q1': 'AA-'},
#  'TRS': {'2023Q3': 'BB-'},
#  'CSV': {'2010Q3': 'B'},
#  'NPO': {'2015Q2': 'BB-'},
#  'NX': {'2018Q4': 'BB-', '2021Q3': 'BB-'},
#  'PLOW': {'2016Q3': 'BB-'},
#  'BERY': {'2023Q4': 'BB-', '2010Q1': 'B-'},
#  'TPC': {'2021Q2': 'BB-'},
#  'EME': {'2012Q4': 'BB+'},
#  'CSL': {'2022Q4': 'BBB'},
#  'URI': {'2011Q2': 'B'},
#  'DLTR': {'2018Q3': 'BB+'},
#  'NNBR': {'2016Q4': 'B+'},
#  'WM': {'2016Q2': 'A-', '2018Q1': 'A-'},
#  'DIN': {'2022Q4': 'B'},
#  'HRB': {'2021Q3': 'BBB'},
#  'HUBB': {'2017Q3': 'A'},
#  'SIG': {'2018Q2': 'BBB-'},
#  'AYI': {'2017Q4': 'BBB'},
#  'IEX': {'2021Q2': 'BBB', '2012Q1': 'BBB'},
#  'TEX': {'2023Q4': 'BB'},
#  'VC': {'2015Q3': 'B+'},
#  'ENR': {'2016Q3': 'BB'},
#  'BECN': {'2019Q2': 'BB-'},
#  'SNA': {'2018Q1': 'A-'},
#  'ETN': {'2018Q3': 'A-'},
#  'HTZ': {'2021Q3': 'B+'},
#  'NWL': {'2017Q1': 'BBB-'},
#  'ROK': {'2024Q1': 'A'},
#  'UL': {'2012Q3': 'A+', '2021Q3': 'A+'},
#  'AZO': {'2022Q3': 'BBB', '2019Q2': 'BBB'},
#  'PM': {'2020Q2': 'A'},
#  'OC': {'2010Q4': 'BBB-'},
#  'ALV': {'2015Q4': 'A-', '2012Q3': 'BBB+'},
#  'EXPE': {'2018Q2': 'BBB-'},
#  'CZR': {'2016Q1': 'B'},
#  'FBIN': {'2016Q4': 'BBB+'},
#  'ANF': {'2017Q4': 'BB-'},
#  'CBRL': {'2019Q3': 'BB-'},
#  'COKE': {'2021Q3': 'BBB'},
#  'OXM': {'2024Q1': 'BB-', '2015Q2': 'BB-'},
#  'XYL': {'2012Q1': 'BBB'},
#  'SWK': {'2020Q2': 'A'},
#  'VAC': {'2018Q1': 'BB+'},
#  'ARMK': {'2014Q2': 'BB'},
#  'HSY': {'2022Q4': 'A'},
#  'CNH': {'2023Q4': 'BB+'},
#  'MDU': {'2022Q3': 'BBB+'},
#  'SPXC': {'2012Q3': 'BB+'},
#  'CMPR': {'2023Q1': 'BB-'},
#  'H': {'2017Q4': 'BBB'},
#  'EFX': {'2010Q2': 'BBB+'},
#  'MKC': {'2012Q3': 'A-'},
#  'ADNT': {'2024Q1': 'BB+'},
#  'SLGN': {'2010Q1': 'BB+'},
#  'DNUT': {'2023Q2': 'B-'},
#  'CONN': {'2024Q1': 'B'}}
