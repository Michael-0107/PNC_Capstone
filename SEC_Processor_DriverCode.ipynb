# %%
import os
import pandas as pd
import importlib

# %%
import Config
importlib.reload(Config)
# Out:
# <module 'Config' from 'g:\\My Drive\\Chronical\\2024_07\\PNC_Capstone\\Config.py'>

# %%
import SEC_Processor
importlib.reload(SEC_Processor)
# Out:
# <module 'SEC_Processor' from 'g:\\My Drive\\Chronical\\2024_07\\PNC_Capstone\\SEC_Processor.py'>

# %%
processor = SEC_Processor.SEC_Processor(year=2024, quarter=1)
walmart_key = processor.get_company_key("WALMART INC.", form='10-K')
print(walmart_key)
# Out:
# 0000104169-24-000056

# %%
walmart_nums = processor.get_company_nums(walmart_key)
for year, year_dict in walmart_nums.items():
    print(year)
    for tag, value in year_dict.items():
        print("    "+tag, value)
# Out:
# 20240131
#     Assets 252399000000.0
#     AssetsCurrent 76877000000.0
#     LiabilitiesCurrent 92415000000.0
#     NetIncomeLoss 15511000000.0
#     OperatingIncomeLoss 27012000000.0
#     PropertyPlantAndEquipmentNet 110810000000.0
#     Revenues 648125000000.0
#     StockholdersEquity 83861000000.0
#     CostOfRevenue 490142000000.0
#     CashAndCashEquivalentsAtCarryingValue 9867000000.0
#     InventoryNet 54892000000.0
#     LongTermDebt 39579000000.0
#     LongTermDebtCurrent 3447000000.0
#     LongTermDebtNoncurrent 36132000000.0
#     NoncurrentAssets 130338000000.0
#     SellingGeneralAndAdministrativeExpense 130971000000.0
# 20230131
#     Assets 243197000000.0
#     AssetsCurrent 75655000000.0
#     LiabilitiesCurrent 92198000000.0
#     NetIncomeLoss 11680000000.0
#     OperatingIncomeLoss 20428000000.0
#     PropertyPlantAndEquipmentNet 100760000000.0
#     Revenues 611289000000.0
#     StockholdersEquity 76693000000.0
#     CostOfRevenue 463721000000.0
#     CashAndCashEquivalentsAtCarryingValue 8625000000.0
#     InventoryNet 56576000000.0
#     LongTermDebt 38840000000.0
#     LongTermDebtCurrent 4191000000.0
#     LongTermDebtNoncurrent 34649000000.0
#     NoncurrentAssets 119234000000.0
#     SellingGeneralAndAdministrativeExpense 127140000000.0
# 20220131
#     Assets 244860000000.0
#     NetIncomeLoss 13673000000.0
#     OperatingIncomeLoss 25942000000.0
#     Revenues 572754000000.0
#     CostOfRevenue 429000000000.0
#     NoncurrentAssets 112624000000.0
#     SellingGeneralAndAdministrativeExpense 117812000000.0

# %%
company_name = "WALMART INC."
results = {}
for year in range(2024, 2019-1, -1):
    processor = SEC_Processor.SEC_Processor(year=year, quarter=1)
    company_key = processor.get_company_key(company_name)
    company_nums = processor.get_company_nums(company_key)
    for year, year_dict in company_nums.items():
        results[year] = year_dict
# Out:
# g:\My Drive\Chronical\2024_07\PNC_Capstone\SEC_Processor.py:15: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.num_df = pd.read_csv(num_path, sep="\t")
# g:\My Drive\Chronical\2024_07\PNC_Capstone\SEC_Processor.py:15: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.num_df = pd.read_csv(num_path, sep="\t")

# %%
for year, year_dict in results.items():
    print(year)
    for tag, value in year_dict.items():
        print("    "+tag, value)
# Out:
# 20240131
#     Assets 252399000000.0
#     AssetsCurrent 76877000000.0
#     LiabilitiesCurrent 92415000000.0
#     NetIncomeLoss 15511000000.0
#     OperatingIncomeLoss 27012000000.0
#     PropertyPlantAndEquipmentNet 110810000000.0
#     Revenues 648125000000.0
#     StockholdersEquity 83861000000.0
#     CostOfRevenue 490142000000.0
#     CashAndCashEquivalentsAtCarryingValue 9867000000.0
#     InventoryNet 54892000000.0
#     LongTermDebt 39579000000.0
#     LongTermDebtCurrent 3447000000.0
#     LongTermDebtNoncurrent 36132000000.0
#     NoncurrentAssets 130338000000.0
#     SellingGeneralAndAdministrativeExpense 130971000000.0
# 20230131
#     Assets 243197000000.0
#     AssetsCurrent 75655000000.0
#     CashAndCashEquivalentsAtCarryingValue 8625000000.0
#     CostOfRevenue 463721000000.0
#     InventoryNet 56576000000.0
#     LiabilitiesCurrent 92198000000.0
#     LongTermDebt 38840000000.0
#     LongTermDebtCurrent 4191000000.0
#     LongTermDebtNoncurrent 34649000000.0
#     NetIncomeLoss 11680000000.0
#     NoncurrentAssets 119234000000.0
#     OperatingIncomeLoss 20428000000.0
#     PropertyPlantAndEquipmentNet 100760000000.0
#     Revenues 611289000000.0
#     SellingGeneralAndAdministrativeExpense 127140000000.0
#     StockholdersEquity 76693000000.0
# 20220131
#     Assets 244860000000.0
#     AssetsCurrent 81070000000.0
#     CashAndCashEquivalentsAtCarryingValue 14760000000.0
#     CostOfRevenue 429000000000.0
#     InventoryNet 56511000000.0
#     LiabilitiesCurrent 87379000000.0
#     LongTermDebt 37667000000.0
#     LongTermDebtCurrent 2803000000.0
#     LongTermDebtNoncurrent 34864000000.0
#     NetIncomeLoss 13673000000.0
#     NoncurrentAssets 112624000000.0
#     OperatingIncomeLoss 25942000000.0
#     PropertyPlantAndEquipmentNet 94515000000.0
#     Revenues 572754000000.0
#     SellingGeneralAndAdministrativeExpense 117812000000.0
#     StockholdersEquity 83253000000.0
# 20210131
#     NetIncomeLoss 13510000000.0
#     PropertyPlantAndEquipmentNet 92201000000.0
#     NoncurrentAssets 109848000000.0
#     LongTermDebtNoncurrent 41194000000.0
#     LiabilitiesCurrent 92645000000.0
#     CostOfRevenue 420315000000.0
#     StockholdersEquity 80925000000.0
#     InventoryNet 44949000000.0
#     OperatingIncomeLoss 22548000000.0
#     Assets 252496000000.0
#     SellingGeneralAndAdministrativeExpense 116288000000.0
#     LongTermDebtCurrent 3115000000.0
#     LongTermDebt 44309000000.0
#     AssetsCurrent 90067000000.0
#     CashAndCashEquivalentsAtCarryingValue 17741000000.0
#     Revenues 559151000000.0
# 20200131
#     Assets 236495000000.0
#     AssetsCurrent 61806000000.0
#     CashAndCashEquivalentsAtCarryingValue 9465000000.0
#     CostOfRevenue 394605000000.0
#     InventoryNet 44435000000.0
#     LiabilitiesCurrent 77790000000.0
#     NetIncomeLoss 14881000000.0
#     PropertyPlantAndEquipmentNet 105208000000.0
#     Revenues 523964000000.0
#     StockholdersEquity 74669000000.0
#     OperatingIncomeLoss 20568000000.0
#     SellingGeneralAndAdministrativeExpense 108791000000.0
#     LongTermDebt 49076000000.0
#     LongTermDebtNoncurrent 43714000000.0
#     LongTermDebtCurrent 5362000000.0
#     NoncurrentAssets 127049000000.0
# 20190131
#     InventoryNet 44269000000.0
#     Assets 219295000000.0
#     AssetsCurrent 61897000000.0
#     LongTermDebt 45396000000.0
#     LongTermDebtCurrent 1876000000.0
#     NetIncomeLoss 6670000000.0
#     LongTermDebtNoncurrent 43520000000.0
#     CashAndCashEquivalentsAtCarryingValue 7722000000.0
#     NoncurrentAssets 111395000000.0
#     LiabilitiesCurrent 77477000000.0
#     PropertyPlantAndEquipmentNet 104317000000.0
#     SellingGeneralAndAdministrativeExpense 107147000000.0
#     StockholdersEquity 72496000000.0
#     CostOfRevenue 385301000000.0
#     Revenues 514405000000.0
#     OperatingIncomeLoss 21957000000.0
# 20191031
#     CostOfRevenue 95900000000.0
#     NetIncomeLoss 3288000000.0
#     Revenues 127991000000.0
# 20190731
#     CostOfRevenue 97923000000.0
#     NetIncomeLoss 3610000000.0
#     Revenues 130377000000.0
# 20190430
#     CostOfRevenue 93034000000.0
#     NetIncomeLoss 3842000000.0
#     Revenues 123925000000.0
# 20181031
#     NetIncomeLoss 1710000000.0
#     CostOfRevenue 93116000000.0
#     Revenues 124894000000.0
# 20180731
#     NetIncomeLoss -861000000.0
#     CostOfRevenue 95571000000.0
#     Revenues 128028000000.0
# 20180430
#     NetIncomeLoss 2134000000.0
#     CostOfRevenue 91707000000.0
#     Revenues 122690000000.0
# 20180131
#     InventoryNet 43783000000.0
#     Assets 204522000000.0
#     AssetsCurrent 59664000000.0
#     LongTermDebt 33783000000.0
#     LongTermDebtCurrent 3738000000.0
#     NetIncomeLoss 9862000000.0
#     LongTermDebtNoncurrent 30045000000.0
#     CashAndCashEquivalentsAtCarryingValue 6756000000.0
#     NoncurrentAssets 114818000000.0
#     LiabilitiesCurrent 78521000000.0
#     PropertyPlantAndEquipmentNet 107675000000.0
#     SellingGeneralAndAdministrativeExpense 106510000000.0
#     StockholdersEquity 77869000000.0
#     CostOfRevenue 373396000000.0
#     Revenues 500343000000.0
#     OperatingIncomeLoss 20437000000.0
# 20171031
#     NetIncomeLoss 1749000000.0
#     CostOfRevenue 91547000000.0
#     Revenues 123179000000.0
# 20170731
#     NetIncomeLoss 2899000000.0
#     CostOfRevenue 91521000000.0
#     Revenues 123355000000.0
# 20170430
#     NetIncomeLoss 3039000000.0
#     CostOfRevenue 87688000000.0
#     Revenues 117542000000.0
# 20170131
#     Assets 198825000000.0
#     NetIncomeLoss 13643000000.0
#     NoncurrentAssets 114178000000.0
#     SellingGeneralAndAdministrativeExpense 101853000000.0
#     CostOfRevenue 361256000000.0
#     Revenues 485873000000.0
#     OperatingIncomeLoss 22764000000.0

# %%
for year, year_dict in results.items():
    print(year)
    for tag, value in year_dict.items():
        print("    "+tag, value)
# Out:
# 20230131
#     Assets 243197000000.0
#     AssetsCurrent 75655000000.0
#     CashAndCashEquivalentsAtCarryingValue 8625000000.0
#     CostOfRevenue 463721000000.0
#     InventoryNet 56576000000.0
#     LiabilitiesCurrent 92198000000.0
#     LongTermDebt 38840000000.0
#     LongTermDebtCurrent 4191000000.0
#     LongTermDebtNoncurrent 34649000000.0
#     NetIncomeLoss 11680000000.0
#     NoncurrentAssets 119234000000.0
#     OperatingIncomeLoss 20428000000.0
#     PropertyPlantAndEquipmentNet 100760000000.0
#     Revenues 611289000000.0
#     SellingGeneralAndAdministrativeExpense 127140000000.0
#     StockholdersEquity 76693000000.0
# 20220131
#     Assets 244860000000.0
#     AssetsCurrent 81070000000.0
#     CashAndCashEquivalentsAtCarryingValue 14760000000.0
#     CostOfRevenue 429000000000.0
#     InventoryNet 56511000000.0
#     LiabilitiesCurrent 87379000000.0
#     LongTermDebt 37667000000.0
#     LongTermDebtCurrent 2803000000.0
#     LongTermDebtNoncurrent 34864000000.0
#     NetIncomeLoss 13673000000.0
#     NoncurrentAssets 112624000000.0
#     OperatingIncomeLoss 25942000000.0
#     PropertyPlantAndEquipmentNet 94515000000.0
#     Revenues 572754000000.0
#     SellingGeneralAndAdministrativeExpense 117812000000.0
#     StockholdersEquity 83253000000.0
# 20210131
#     NetIncomeLoss 13510000000.0
#     PropertyPlantAndEquipmentNet 92201000000.0
#     NoncurrentAssets 109848000000.0
#     LongTermDebtNoncurrent 41194000000.0
#     LiabilitiesCurrent 92645000000.0
#     CostOfRevenue 420315000000.0
#     StockholdersEquity 80925000000.0
#     InventoryNet 44949000000.0
#     OperatingIncomeLoss 22548000000.0
#     Assets 252496000000.0
#     SellingGeneralAndAdministrativeExpense 116288000000.0
#     LongTermDebtCurrent 3115000000.0
#     LongTermDebt 44309000000.0
#     AssetsCurrent 90067000000.0
#     CashAndCashEquivalentsAtCarryingValue 17741000000.0
#     Revenues 559151000000.0
# 20200131
#     Assets 236495000000.0
#     AssetsCurrent 61806000000.0
#     CashAndCashEquivalentsAtCarryingValue 9465000000.0
#     CostOfRevenue 394605000000.0
#     InventoryNet 44435000000.0
#     LiabilitiesCurrent 77790000000.0
#     NetIncomeLoss 14881000000.0
#     PropertyPlantAndEquipmentNet 105208000000.0
#     Revenues 523964000000.0
#     StockholdersEquity 74669000000.0
#     OperatingIncomeLoss 20568000000.0
#     SellingGeneralAndAdministrativeExpense 108791000000.0
#     LongTermDebt 49076000000.0
#     LongTermDebtNoncurrent 43714000000.0
#     LongTermDebtCurrent 5362000000.0
#     NoncurrentAssets 127049000000.0
# 20190131
#     InventoryNet 44269000000.0
#     Assets 219295000000.0
#     AssetsCurrent 61897000000.0
#     LongTermDebt 45396000000.0
#     LongTermDebtCurrent 1876000000.0
#     NetIncomeLoss 6670000000.0
#     LongTermDebtNoncurrent 43520000000.0
#     CashAndCashEquivalentsAtCarryingValue 7722000000.0
#     NoncurrentAssets 111395000000.0
#     LiabilitiesCurrent 77477000000.0
#     PropertyPlantAndEquipmentNet 104317000000.0
#     SellingGeneralAndAdministrativeExpense 107147000000.0
#     StockholdersEquity 72496000000.0
#     CostOfRevenue 385301000000.0
#     Revenues 514405000000.0
#     OperatingIncomeLoss 21957000000.0
# 20191031
#     CostOfRevenue 95900000000.0
#     NetIncomeLoss 3288000000.0
#     Revenues 127991000000.0
# 20190731
#     CostOfRevenue 97923000000.0
#     NetIncomeLoss 3610000000.0
#     Revenues 130377000000.0
# 20190430
#     CostOfRevenue 93034000000.0
#     NetIncomeLoss 3842000000.0
#     Revenues 123925000000.0
# 20181031
#     NetIncomeLoss 1710000000.0
#     CostOfRevenue 93116000000.0
#     Revenues 124894000000.0
# 20180731
#     NetIncomeLoss -861000000.0
#     CostOfRevenue 95571000000.0
#     Revenues 128028000000.0
# 20180430
#     NetIncomeLoss 2134000000.0
#     CostOfRevenue 91707000000.0
#     Revenues 122690000000.0
# 20180131
#     InventoryNet 43783000000.0
#     Assets 204522000000.0
#     AssetsCurrent 59664000000.0
#     LongTermDebt 33783000000.0
#     LongTermDebtCurrent 3738000000.0
#     NetIncomeLoss 9862000000.0
#     LongTermDebtNoncurrent 30045000000.0
#     CashAndCashEquivalentsAtCarryingValue 6756000000.0
#     NoncurrentAssets 114818000000.0
#     LiabilitiesCurrent 78521000000.0
#     PropertyPlantAndEquipmentNet 107675000000.0
#     SellingGeneralAndAdministrativeExpense 106510000000.0
#     StockholdersEquity 77869000000.0
#     CostOfRevenue 373396000000.0
#     Revenues 500343000000.0
#     OperatingIncomeLoss 20437000000.0
# 20171031
#     NetIncomeLoss 1749000000.0
#     CostOfRevenue 91547000000.0
#     Revenues 123179000000.0
# 20170731
#     NetIncomeLoss 2899000000.0
#     CostOfRevenue 91521000000.0
#     Revenues 123355000000.0
# 20170430
#     NetIncomeLoss 3039000000.0
#     CostOfRevenue 87688000000.0
#     Revenues 117542000000.0
# 20170131
#     Assets 198825000000.0
#     NetIncomeLoss 13643000000.0
#     NoncurrentAssets 114178000000.0
#     SellingGeneralAndAdministrativeExpense 101853000000.0
#     CostOfRevenue 361256000000.0
#     Revenues 485873000000.0
#     OperatingIncomeLoss 22764000000.0
